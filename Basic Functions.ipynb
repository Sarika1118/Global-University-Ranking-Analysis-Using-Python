# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ### Reading dataset:

# %%
df=pd.read_csv("C:\\Users\\CSE\\Downloads\\archive (6)\\world_university_rank.csv")
df
# Out:
#           Rank                        University name locationLocation  \
# 0            1                   University of Oxford   United Kingdom
# 1            2                     Harvard University    United States
# 2            3                University of Cambridge   United Kingdom
# 3            3                    Stanford University    United States
# 4            5  Massachusetts Institute of Technology    United States
# ...        ...                                    ...              ...
# 2340  Reporter                York St John University   United Kingdom
# 2341  Reporter    Yusuf Maitama Sule University, Kano          Nigeria
# 2342  Reporter  Zhytomyr Polytechnic State University          Ukraine
# 2343  Reporter                    Ziauddin University         Pakistan
# 2344  Reporter                       Zarqa University           Jordan
#
#      Number of Studnet  Number of student per staffs International Student  \
# ...

# %% [markdown]
# ## Applying some basic functions:
# - shape
# - colums
# - head()
# - tail()
# - count()
# - value_counts()
# - info
# - describe

# %%
# To print the number of rows and columns..
df.shape
# Out:
# (2345, 7)

# %%
#To print the column names
df.columns
# Out:
# Index(['Rank', 'University name', 'locationLocation', 'Number of Studnet',
#        'Number of student per staffs', 'International Student',
#        'Female : male ratio'],
#       dtype='object')

# %%
#head()- prints the first five records of dataset
df.head()
# Out:
#   Rank                        University name locationLocation  \
# 0    1                   University of Oxford   United Kingdom
# 1    2                     Harvard University    United States
# 2    3                University of Cambridge   United Kingdom
# 3    3                    Stanford University    United States
# 4    5  Massachusetts Institute of Technology    United States
#
#   Number of Studnet  Number of student per staffs International Student  \
# 0            20,965                          10.6                   42%
# 1            21,887                           9.6                   25%
# 2            20,185                          11.3                   39%
# 3            16,164                           7.1                   24%
# 4            11,415                           8.2                   33%
#
#   Female : male ratio
# 0             48 : 52
# 1             50 : 50
# 2             47 : 53
# 3             46 : 54
# 4             40 : 60

# %%
#tail()- prints the last five records of dataset
df.tail()
# Out:
#           Rank                        University name locationLocation  \
# 2340  Reporter                York St John University   United Kingdom
# 2341  Reporter    Yusuf Maitama Sule University, Kano          Nigeria
# 2342  Reporter  Zhytomyr Polytechnic State University          Ukraine
# 2343  Reporter                    Ziauddin University         Pakistan
# 2344  Reporter                       Zarqa University           Jordan
#
#      Number of Studnet  Number of student per staffs International Student  \
# 2340             6,315                          18.6                   12%
# 2341            12,880                          33.0                    0%
# 2342             3,869                          15.4                    1%
# 2343             4,906                           8.8                    1%
# 2344             5,768                          18.1                   32%
#
#      Female : male ratio
# 2340             65 : 35
# 2341             48 : 52
# ...

# %%
df.columns=['Rank','University name','Location','Number of Students','Number of students per staff','International students','Femal:Male Ratio']
df
# Out:
#           Rank                        University name        Location  \
# 0            1                   University of Oxford  United Kingdom
# 1            2                     Harvard University   United States
# 2            3                University of Cambridge  United Kingdom
# 3            3                    Stanford University   United States
# 4            5  Massachusetts Institute of Technology   United States
# ...        ...                                    ...             ...
# 2340  Reporter                York St John University  United Kingdom
# 2341  Reporter    Yusuf Maitama Sule University, Kano         Nigeria
# 2342  Reporter  Zhytomyr Polytechnic State University         Ukraine
# 2343  Reporter                    Ziauddin University        Pakistan
# 2344  Reporter                       Zarqa University          Jordan
#
#      Number of Students  Number of students per staff International students  \
# ...

# %%
# count()-prints the number of records in each attribute.
df.count()
# Out:
# Rank                            2345
# University name                 2345
# Location                        2234
# Number of Students              2345
# Number of students per staff    2344
# International students          2345
# Femal:Male Ratio                2255
# dtype: int64

# %%
# To count the different universities
df['University name'].value_counts()
# Out:
# University of Oxford                              1
# Federal University of Agriculture, Abeokuta       1
# Cukurova University                               1
# University of Dar es Salaam                       1
# Dicle University                                  1
#                                                  ..
# University of Texas at Arlington                  1
# The University of Texas at San Antonio            1
# Thapar Institute of Engineering and Technology    1
# University of Toledo                              1
# Zarqa University                                  1
# Name: University name, Length: 2345, dtype: int64

# %%
df['Location'].value_counts()
# Out:
# United States     179
# United Kingdom    163
# Japan             152
# India             101
# China              95
#                  ...
# Jamaica             1
# Nepal               1
# Mozambique          1
# Malta               1
# Kosovo              1
# Name: Location, Length: 117, dtype: int64

# %%
# To get the information about the dataset..
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2345 entries, 0 to 2344
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Rank                          2345 non-null   object
#  1   University name               2345 non-null   object
#  2   Location                      2234 non-null   object
#  3   Number of Students            2345 non-null   object
#  4   Number of students per staff  2344 non-null   float64
#  5   International students        2345 non-null   object
#  6   Femal:Male Ratio              2255 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 128.4+ KB

# %%
df['Number of Students']=df['Number of Students'].str.replace(',', '').astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2345 entries, 0 to 2344
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Rank                          2345 non-null   object
#  1   University name               2345 non-null   object
#  2   Location                      2234 non-null   object
#  3   Number of Students            2345 non-null   int32
#  4   Number of students per staff  2344 non-null   float64
#  5   International students        2345 non-null   object
#  6   Femal:Male Ratio              2255 non-null   object
# dtypes: float64(1), int32(1), object(5)
# memory usage: 119.2+ KB

# %%
# To find the count,mean,std,min,max..
df.describe()
# Out:
#        Number of Students  Number of students per staff
# count         2345.000000                   2344.000000
# mean         19220.701066                     18.722056
# std          24575.292996                     11.921330
# min            115.000000                      0.400000
# 25%           6988.000000                     12.300000
# 50%          13956.000000                     16.300000
# 75%          25215.000000                     21.900000
# max         460632.000000                    232.200000

# %%
# To get unique values from university names
df['University name'].unique()
# Out:
# array(['University of Oxford', 'Harvard University',
#        'University of Cambridge', ...,
#        'Zhytomyr Polytechnic State University', 'Ziauddin University',
#        'Zarqa University'], dtype=object)

# %%
# returns the number of unique values for each column
df.nunique()
# Out:
# Rank                             161
# University name                 2345
# Location                         117
# Number of Students              2260
# Number of students per staff     424
# International students            79
# Femal:Male Ratio                  87
# dtype: int64

# %% [markdown]
# ### Data Filtering:

# %%
### Universities that contain greater than 10000 students
df[df['Number of Students']>10000]
# Out:
#           Rank                          University name        Location  \
# 0            1                     University of Oxford  United Kingdom
# 1            2                       Harvard University   United States
# 2            3                  University of Cambridge  United Kingdom
# 3            3                      Stanford University   United States
# 4            5    Massachusetts Institute of Technology   United States
# ...        ...                                      ...             ...
# 2328  Reporter                 West Virginia University   United States
# 2331  Reporter             Uzhhorod National University         Ukraine
# 2338  Reporter  Yanka Kupala State University of Grodno             NaN
# 2339  Reporter              Yogyakarta State University       Indonesia
# 2341  Reporter      Yusuf Maitama Sule University, Kano         Nigeria
#
#       Number of Students  Number of students per staff International students  \
# ...

# %%
### Universities that contain less than 1000 students
data=df[df['Number of Students']<1000]
data.head(10)
# Out:
#            Rank                                    University name  \
# 183         183                   Scuola Normale Superiore di Pisa
# 653     601–800                                     ENSTA Bretagne
# 917    801–1000  École Nationale des Travaux Publics de l'État ...
# 926    801–1000                              Nippon Medical School
# 1067  1001–1200                          Hyogo College of Medicine
# 1171  1001–1200          St Marianna University School of Medicine
# 1184  1001–1200                     Toyota Technological Institute
# 1803   Reporter                            AECC University College
# 1810   Reporter                   Tashkent Metropolitan University
# 1835   Reporter              American University of Ras Al Khaimah
#
#                   Location  Number of Students  Number of students per staff  \
# 183                  Italy                 629                           7.6
# ...

# %%
df[df['Location']=='United States'].head(10)
# Out:
#    Rank                        University name       Location  \
# 1     2                     Harvard University  United States
# 3     3                    Stanford University  United States
# 4     5  Massachusetts Institute of Technology  United States
# 5     6     California Institute of Technology  United States
# 6     7                   Princeton University  United States
# 7     8     University of California, Berkeley  United States
# 8     9                        Yale University  United States
# 10   11                    Columbia University  United States
# 12   13              The University of Chicago  United States
# 13   14             University of Pennsylvania  United States
#
#     Number of Students  Number of students per staff International students  \
# 1                21887                           9.6                    25%
# 3                16164                           7.1                    24%
# ...

# %%
data=df[df['Location']=='India'].head(10)
data
# Out:
#         Rank                                    University name Location  \
# 273  251–300                        Indian Institute of Science    India
# 372  351–400       JSS Academy of Higher Education and Research    India
# 389  351–400  Shoolini University of Biotechnology and Manag...    India
# 400  401–500                                Alagappa University    India
# 453  401–500                          Mahatma Gandhi University    India
# 534  501–600               Indian Institute of Technology Ropar    India
# 536  501–600  International Institute of Information Technol...    India
# 540  501–600                               Jamia Millia Islamia    India
# 573  501–600  Saveetha Institute of Medical and Technical Sc...    India
# 617  601–800                           Banaras Hindu University    India
#
#      Number of Students  Number of students per staff International students  \
# 273                3990                           8.8                     1%
# ...

# %%
df[df['University name'].str.startswith('A')]
# Out:
#           Rank                                    University name  \
# 61          62                     Australian National University
# 116        117                                  Aarhus University
# 155        156                   Arizona State University (Tempe)
# 182        183                 Autonomous University of Barcelona
# 200    201–250                                   Aalto University
# ...        ...                                                ...
# 1854  Reporter                                           Audencia
# 1855  Reporter                               Augustine University
# 1856  Reporter  Azerbaijan University of Architecture and Cons...
# 1857  Reporter           Azerbaijan State University of Economics
# 1947  Reporter             Academy of Economic Studies of Moldova
#
#            Location  Number of Students  Number of students per staff  \
# 61        Australia               16758                          14.6
# ...

# %%
## Unviersities that contains maximum rate of international students
df[df['International students']==df['International students'].max()]
# Out:
#           Rank                  University name     Location  \
# 1903  Reporter  César Ritz Colleges Switzerland  Switzerland
#
#       Number of Students  Number of students per staff International students  \
# 1903                 547                           4.8                    99%
#
#      Femal:Male Ratio
# 1903          49 : 51

# %%
## Records of Unversities that hava maximum ratio of female and male
df1=df.sort_values('Femal:Male Ratio',ascending=False).head(20)
df1
# Out:
#            Rank                                    University name  \
# 1950   Reporter                                   Effat University
# 1245  1201–1500    Chang Gung University of Science and Technology
# 678     601–800             Imam Abdulrahman Bin Faisal University
# 2277   Reporter                Tashkent State Transport University
# 599     501–600                                   Zayed University
# 2337   Reporter                   Yamaguchi Prefectural University
# 2161   Reporter                          Nursing School of Coimbra
# 2317   Reporter  University of Veterinary Medicine and Pharmacy...
# 2247   Reporter  Sri Padmavati Mahila Visvavidyalayam (Women's ...
# 1913   Reporter                         Courtauld Institute of Art
# 1821   Reporter  Alisher Navo’i Tashkent State University of Uz...
# 2044   Reporter  Kharkiv University of Humanities “People’s Ukr...
# 297     251–300                    United Arab Emirates University
# ...

# %%
# To print the Maximum and Minimum number of students University records??
df[(df['Number of Students']==df['Number of Students'].max())|(df['Number of Students']==df['Number of Students'].min())]
# Out:
#           Rank                 University name Location  Number of Students  \
# 986   801–1000            Tribhuvan University    Nepal              460632
# 2099  Reporter  MIOTI Tech and Business School    Spain                 115
#
#       Number of students per staff International students Femal:Male Ratio
# 986                           30.9                     0%          50 : 50
# 2099                          38.3                     9%          31 : 69

# %%
## print the Maximum no.of students per staff record
df[df['Number of students per staff']==df['Number of students per staff'].max()]
# Out:
#            Rank             University name      Location  Number of Students  \
# 1164  1001–1200  University of South Africa  South Africa              236282
#
#       Number of students per staff International students Femal:Male Ratio
# 1164                         232.2                     3%          73 : 27

# %%
# To print the Maximum and Minimum number of students University records??
df[(df['Number of students per staff']==df['Number of students per staff'].max())|(df['Number of students per staff']==df['Number of students per staff'].min())]
# Out:
#            Rank                                    University name  \
# 1164  1001–1200                         University of South Africa
# 1985   Reporter  The Graduate University for Advanced Studies, ...
#
#           Location  Number of Students  Number of students per staff  \
# 1164  South Africa              236282                         232.2
# 1985         Japan                 506                           0.4
#
#      International students Femal:Male Ratio
# 1164                     3%          73 : 27
# 1985                    31%          29 : 71

# %% [markdown]
# ### Aggregations:
# - mean()
# - median()
# - max()
# - min()
# - std()
# - var()

# %%
df.mean()
# Out:
# C:\Users\W.10\AppData\Local\Temp\ipykernel_10772\3698961737.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Number of Students              19220.701066
# Number of students per staff       18.722056
# dtype: float64

# %%
df.median()
# Out:
# C:\Users\W.10\AppData\Local\Temp\ipykernel_10772\530051474.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# Number of Students              13956.0
# Number of students per staff       16.3
# dtype: float64

# %%
df['Number of Students'].max()
# Out:
# 460632

# %%
df['Number of Students'].min()
# Out:
# 115

# %%
df.std()
# Out:
# C:\Users\W.10\AppData\Local\Temp\ipykernel_10772\3390915376.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std()
# Number of Students              24575.292996
# Number of students per staff       11.921330
# dtype: float64

# %%
df.var()
# Out:
# C:\Users\W.10\AppData\Local\Temp\ipykernel_10772\1568254755.py:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.var()
# Number of Students              6.039450e+08
# Number of students per staff    1.421181e+02
# dtype: float64
